# %% [markdown]
# # Домашнее задание 1
#
# ## Математические методы анализа данных
#
# В этом задании вы потренируетесь работать с базовыми структурами Python, библиотекой `NumPy` и инструментами первичного анализа данных.
# - Первая часть посвящена отработке навыков использования `NumPy`.
# - Вторая часть посвящена датасету с характеристиками автомобилей и подготовке данных к дальнейшему моделированию.
#
# **Максимальный балл за задание: 10.**

# %% [markdown]
# ## <font color="red">Правила выполнения домашних заданий</font>
#
# - При использовании LLM или других интернет-решений для выполнения заданий необходимо написать об этом в ячейке рядом или в markdown текстом (какая LLM была использована для создания кода или какой ресурс)
#
# - При использовании внешних знаний (LLM, интернет) для выполнения заданий необходимо разобраться и полностью понять решение, которое вы используете
#
# - Примерно 10% домашних заданий случайно будут выбраны после дедлайна, и авторы заданий будут приглашены на устную защиту заданий. Если по результатам устного разговора автор не сможет показать понимания кода - задание будет обнулено.

# %% [markdown]
# ## Общие требования к ДЗ-1
#
# - Для каждого задания приведите код решения.
# - Там, где требуется интерпретация, добавьте короткий текстовый вывод.
# - Следите за тем, чтобы ноутбук выполнялся последовательно сверху вниз.
# - В EDA-части все значения для обработки тестовой выборки рассчитывайте только по тренировочной выборке.
#
# > В каждой части оцениваются как код, так и ответы на вопросы. Если отсутствует одно из двух, часть баллов за соответствующее задание может быть снижена.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## <font color="green">Часть 1. Python и NumPy (3 балла, каждый пункт весит 3/8=0.375 балла)</font>
#
# Цель этой части - сравнить ручную реализацию матричных операций на стандартных списках Python с реализацией на `NumPy`.

# %% [markdown]
# ![ChatGPT Image 20 сент. 2026 г., 18_47_57.png](data:image/png;base64,...)

# %% [markdown]
# 1. Реализуйте функцию `fib_func(n)`, которая возвращает список из первых `n` чисел последовательности Фибоначчи.

# %%
# ваше решение здесь

# %% [markdown]
# 2. Реализуйте функцию `matrix_func(arr, i, j)`, которая принимает список `arr` и два целых числа `i` и `j`, а затем возвращает матрицу размера `i × j`, представленную в виде списка из `i` списков по `j` элементов.
#
#    Элементы списка `arr` должны последовательно заполнять строки матрицы. Если количество элементов в `arr` не равно `i * j`, функция должна сообщить об ошибке.

# %%
# ваше решение здесь

# %% [markdown]
# 3. Реализуйте функцию умножения двух матриц, используя только стандартные средства Python: списки, циклы и арифметические операции. Использовать `NumPy` для выполнения умножения в этой функции нельзя.
#
#    Функция должна проверять, возможно ли умножение заданных матриц, и сообщать об ошибке, если их размеры несовместимы.

# %%
# ваше решение здесь

# %% [markdown]
# 4. Создайте две квадратные матрицы одинакового размера и выполните их умножение с помощью функции из пункта 3. Измерьте время выполнения только операции умножения. Для измерения времени рекомендуется использовать `time.perf_counter()` или модуль `timeit`.

# %%
# ваше решение здесь

# %% [markdown]
# 5. Преобразуйте те же исходные матрицы в массивы `NumPy` и выполните их умножение средствами `NumPy`. Измерьте время выполнения операции умножения. Время преобразования списков в массивы `NumPy` учитывать не нужно.

# %%
# ваше решение здесь

# %% [markdown]
# 6. Проведите эксперимент для нескольких размеров квадратных матриц, например `50 × 50`, `100 × 100` и `200 × 200`.
#
#    Для каждого размера используйте одинаковые исходные данные при сравнении реализации на стандартных списках Python и реализации с использованием `NumPy`.

# %%
# ваше решение здесь

# %% [markdown]
# 7. Представьте результаты в виде таблицы со следующими столбцами:
#
#    | Столбец | Описание |
#    | --- | --- |
#    | Размер матрицы | Размер квадратной матрицы |
#    | Время Python | Время выполнения реализации на стандартных списках |
#    | Время NumPy | Время выполнения реализации на `NumPy` |
#    | Отношение времен | Во сколько раз Python-реализация медленнее или быстрее `NumPy` |

# %%
# ваше решение здесь

# %% [markdown]
# 8. Прокомментируйте полученные результаты. Какая реализация работает быстрее? Как меняется разница во времени работы при увеличении размера матриц?

# %%
# ваше решение здесь

# %% [markdown]
# ## <font color="green">Часть 2. Exploratory Data Analysis (7 баллов; каждый пункт, кроме первого, весит 7/10=0.7 баллов)</font>
#
# В этой части вам предстоит провести первичный анализ данных об автомобилях, подготовить признаки к дальнейшей работе и сделать выводы о структуре датасета.
#
# ### Данные
#
# Используйте файлы:
#
# - `new_cars_train.csv` — тренировочный набор данных;
# - `new_cars_test.csv` — тестовый набор данных.
#
# ### План работы
#
# 1. Выполнить первичный просмотр данных.
# 2. Проверить типы признаков и соответствие типов смыслу данных.
# 3. Привести строковые числовые признаки к корректному формату.
# 4. Обработать пропуски без использования информации из тестовой выборки.
# 5. Проверить данные на дубли.
# 6. Посчитать дескриптивные статистики.
# 7. Построить визуализации и проанализировать связи между признаками.

# %% [markdown]
# ![ChatGPT Image 20 сент. 2026 г., 18_50_17.png](data:image/png;base64,...)

# %% [markdown]
# ### Задание 2.1. Первичный просмотр данных (0 баллов)
#
# 1. Загрузите тренировочный и тестовый наборы данных в pandas dataframes.
# 2. Выведите размеры обоих датасетов.
# 3. Отобразите первые 3 и последние 3 строки тренировочного датасета.
# 4. Отобразите 3 случайные строки тестового датасета.

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/paiflare/ml_hse_2026/refs/heads/master/homework/hw_1/Data/new_cars_train.csv')
df_test = pd.read_csv('https://raw.githubusercontent.com/paiflare/ml_hse_2026/refs/heads/master/homework/hw_1/Data/new_cars_test.csv')

print("Train data shape:", df_train.shape)
print("Test data shape: ", df_test.shape)

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.2. Проверка типов признаков
#
# 1. Выведите типы данных всех столбцов.
# 2. Выведите примеры значений или краткое описание признаков.
# 3. Проверьте, соответствуют ли типы данных смыслу признаков.
# 4. Укажите признаки, которые хранятся в таблице в некорректном формате и потому требуют преобразования.
#
# Для анализа можно использовать методы `.dtypes`, `.info()`, `.describe()` или другой удобный способ.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.3. Коррекция строковых числовых признаков
#
# Признаки `mileage`, `engine`, `max_power` и `torque` не являются категориальными по смыслу. Однако из-за единиц измерения и неоднородного формата они могут распознаваться как строки.
#
# 1. Уберите единицы измерения и приведите к числовому типу признаки `mileage`, `engine` и `max_power`.
# 2. Признак `torque` имеет неоднородный строковый формат. В рамках этого задания удалите этот столбец, чтобы не усложнять предобработку.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.4. Преобразование признака `km_driven`
#
# Признак `km_driven` на первый взгляд содержит только числа, но может быть сохранен в некорректном формате.
#
# 1. Приведите все значения признака `km_driven` к числовому типу данных.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.5. Обработка пропусков
#
# 1. Проверьте, есть ли в датасетах пропуски.
# 2. Выведите названия колонок, в которых пропущены значения, и количество таких значений в каждой колонке.
# 3. Выберите корректную стратегию заполнения пропусков.
# 4. Объясните текстом в markdown, почему была выбрана именно эта стратегия?
#
# **Важно:** в реальной задаче на этапе обучения модели нельзя использовать информацию из тестовой выборки. Поэтому значения для заполнения пропусков нужно рассчитывать только по тренировочному набору данных, а затем применять их и к тренировочной, и к тестовой выборке.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.6. Приведение `seats` к целочисленному типу
#
# После обработки пропусков в колонке `seats` должны остаться только целые значения.
#
# - Приведите признак `seats` к типу `int`.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.7. Удаление дублей
#
# 1. Проверьте, есть ли в тренировочном и тестовом наборах данных явные дубли.
# 2. Проверьте, есть ли объекты с одинаковым признаковым описанием. Для тренировочной выборки целевую переменную следует исключить из проверки.
# 3. Отобразите найденные объекты.
# 4. Удалите повторяющиеся строки.
# 5. Если при одинаковом признаковом описании значения целевой переменной отличаются, оставьте первое встретившееся наблюдение среди таких строк.
# 6. Обновите индексы строк таким образом, чтобы они шли от 0 без пропусков.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.8. Описательные статистики
#
# 1. С помощью метода `.describe()` посчитайте основные статистики по числовым столбцам для тренировочного и тестового наборов данных.
# 2. С помощью метода `.describe()` посчитайте основные статистики по категориальным столбцам для тренировочного и тестового наборов данных.
# 3. Сделайте выводы по описательным статистикам - текстом в markdown.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.9. Визуализация распределений
#
# 1. Используйте `pairplot` из библиотеки `seaborn`, чтобы визуализировать попарные распределения числовых признаков для тренировочного набора данных.
# 2. Ответьте, можно ли на основе распределений предположить связь признаков с целевой переменной?
# 3. Ответьте, можно ли на основе распределений выдвинуть гипотезу о корреляции признаков?

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.10. Корреляционный анализ
#
# После визуального анализа оцените связи между числовыми признаками количественно.
#
# 1. Получите значения коэффициента корреляции Пирсона для тренировочного набора данных с помощью метода `.corr()`.
# 2. По полученным корреляциям постройте тепловую карту с помощью `heatmap` из библиотеки `seaborn`.

# %%
# ваше решение здесь

# %% [markdown]
# ### Задание 2.11. Интерпретация результатов
#
# Ответьте на вопросы:
#
# 1. `selling_price` - это целевая переменная. Что можно сказать о влиянии признаков на целевую переменную по матрице корреляций? Как думаете, осмысленно ли будет применять модели машинного обучения для её прогнозирования?
# 2. Какие 2 признака наименее скоррелированы между собой?
# 3. Между какими признаками наблюдается довольно сильная положительная линейная зависимость?
# 4. Правильно ли, опираясь на данные, утверждать, что чем меньше год выпуска автомобиля, тем больше километров он, скорее всего, проехал к дате продажи?

# %%
# ваше решение здесь
